# %% [markdown]
# ## Scenario 2: A cross-functional team with one data scientist working on an ML model
#
#
# MLflow setup:
# - tracking server: yes, local server
# - backend store: sqlite database
# - artifacts store: local filesystem
#
# The experiments can be explored locally by accessing the local tracking server.
#
# To run this example you need to launch the mlflow server locally by running the following command in your terminal:
#
# `mlflow server --backend-store-uri sqlite:///backend.db`

# %%
import mlflow


mlflow.set_tracking_uri("http://127.0.0.1:5000")

# %%
print(f"tracking URI: '{mlflow.get_tracking_uri()}'")
# Out:
# tracking URI: 'http://127.0.0.1:5000'

# %%
mlflow.search_experiments()
# Out:
# [<Experiment: artifact_location='/home/oduorri/mlops-zoomcamp/mlops-zoomcamp/02-experiment-tracking/running-mlflow-examples/artifacts_local/0', creation_time=1750171949113, experiment_id='0', last_update_time=1750171949113, lifecycle_stage='active', name='Default', tags={}>]

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.datasets import load_iris
from sklearn.metrics import accuracy_score

mlflow.set_experiment("my-experiment-1")

with mlflow.start_run():

    X, y = load_iris(return_X_y=True)

    params = {"C": 0.1, "random_state": 42}
    mlflow.log_params(params)

    lr = LogisticRegression(**params).fit(X, y)
    y_pred = lr.predict(X)
    mlflow.log_metric("accuracy", accuracy_score(y, y_pred))

    mlflow.sklearn.log_model(lr, artifact_path="models")
    print(f"default artifacts URI: '{mlflow.get_artifact_uri()}'")
# Out:
# 2025/06/17 14:56:38 INFO mlflow.tracking.fluent: Experiment with name 'my-experiment-1' does not exist. Creating a new experiment.
# 2025/06/17 14:56:42 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# default artifacts URI: '/home/oduorri/mlops-zoomcamp/mlops-zoomcamp/02-experiment-tracking/running-mlflow-examples/artifacts_local/1/024cb02511a64b768561b6a74560e0a7/artifacts'
# 🏃 View run intelligent-pig-248 at: http://127.0.0.1:5000/#/experiments/1/runs/024cb02511a64b768561b6a74560e0a7
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/1

# %%
mlflow.search_experiments()
# Out:
# [<Experiment: artifact_location='/home/oduorri/mlops-zoomcamp/mlops-zoomcamp/02-experiment-tracking/running-mlflow-examples/artifacts_local/1', creation_time=1750172198158, experiment_id='1', last_update_time=1750172198158, lifecycle_stage='active', name='my-experiment-1', tags={}>,
#  <Experiment: artifact_location='/home/oduorri/mlops-zoomcamp/mlops-zoomcamp/02-experiment-tracking/running-mlflow-examples/artifacts_local/0', creation_time=1750171949113, experiment_id='0', last_update_time=1750171949113, lifecycle_stage='active', name='Default', tags={}>]

# %% [markdown]
# ### Interacting with the model registry

# %%
from mlflow.tracking import MlflowClient


client = MlflowClient("http://127.0.0.1:5000")

# %%
client.search_registered_models()
# Out:
# [<RegisteredModel: aliases={}, creation_timestamp=1750172235775, description='', last_updated_timestamp=1750172235815, latest_versions=[<ModelVersion: aliases=[], creation_timestamp=1750172235815, current_stage='None', description='', last_updated_timestamp=1750172235815, name='iris-classifier', run_id='024cb02511a64b768561b6a74560e0a7', run_link='', source='/home/oduorri/mlops-zoomcamp/mlops-zoomcamp/02-experiment-tracking/running-mlflow-examples/artifacts_local/1/024cb02511a64b768561b6a74560e0a7/artifacts/models', status='READY', status_message=None, tags={}, user_id='', version='1'>], name='iris-classifier', tags={}>]

# %%
run_id = client.search_runs(experiment_ids='1')[0].info.run_id
mlflow.register_model(
    model_uri=f"runs:/{run_id}/models",
    name='iris-classifier'
)
# Out:
# Successfully registered model 'iris-classifier'.
# 2025/06/17 14:57:15 INFO mlflow.store.model_registry.abstract_store: Waiting up to 300 seconds for model version to finish creation. Model name: iris-classifier, version 1
# Created version '1' of model 'iris-classifier'.
# <ModelVersion: aliases=[], creation_timestamp=1750172235815, current_stage='None', description='', last_updated_timestamp=1750172235815, name='iris-classifier', run_id='024cb02511a64b768561b6a74560e0a7', run_link='', source='/home/oduorri/mlops-zoomcamp/mlops-zoomcamp/02-experiment-tracking/running-mlflow-examples/artifacts_local/1/024cb02511a64b768561b6a74560e0a7/artifacts/models', status='READY', status_message=None, tags={}, user_id='', version='1'>
